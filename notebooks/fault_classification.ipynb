# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('../data/cnc_lathe_dataset.csv')

# %%
df
# Out:
#       sample_id  timestamp_s  spindle_speed_rpm  feed_rate_mm_min  \
# 0             1         12.5               1319             183.8
# 1             2         20.5               1280             136.4
# 2             3         34.6                993             158.1
# 3             4         47.7               1276             205.1
# 4             5         62.1               1086             186.0
# ...         ...          ...                ...               ...
# 1995       1996      23165.2               1049             179.0
# 1996       1997      23178.3                885             174.9
# 1997       1998      23192.1               1260             198.8
# 1998       1999      23201.4               1245             146.0
# 1999       2000      23211.3               1078             206.1
#
#       depth_of_cut_mm  cutting_speed_m_min  material_hardness_HRC  \
# 0                1.61                 0.33                   47.9
# ...

# %%
df.isnull().sum()
# Out:
# sample_id                  0
# timestamp_s                0
# spindle_speed_rpm          0
# feed_rate_mm_min           0
# depth_of_cut_mm            0
# cutting_speed_m_min        0
# material_hardness_HRC      0
# spindle_motor_current_A    0
# spindle_torque_Nm          0
# spindle_temp_C             0
# coolant_temp_C             0
# ambient_temp_C             0
# vibration_x_g              0
# vibration_y_g              0
# vibration_z_g              0
# surface_roughness_Ra       0
# dimensional_error_mm       0
# tool_wear_mm               0
# cycle_time_s               0
# tool_condition             0
# fault_label                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['sample_id', 'timestamp_s', 'spindle_speed_rpm', 'feed_rate_mm_min',
#        'depth_of_cut_mm', 'cutting_speed_m_min', 'material_hardness_HRC',
#        'spindle_motor_current_A', 'spindle_torque_Nm', 'spindle_temp_C',
#        'coolant_temp_C', 'ambient_temp_C', 'vibration_x_g', 'vibration_y_g',
#        'vibration_z_g', 'surface_roughness_Ra', 'dimensional_error_mm',
#        'tool_wear_mm', 'cycle_time_s', 'tool_condition', 'fault_label'],
#       dtype='object')

# %%
df.drop(columns=['tool_condition'], inplace=True)

# %%
df.columns
# Out:
# Index(['sample_id', 'timestamp_s', 'spindle_speed_rpm', 'feed_rate_mm_min',
#        'depth_of_cut_mm', 'cutting_speed_m_min', 'material_hardness_HRC',
#        'spindle_motor_current_A', 'spindle_torque_Nm', 'spindle_temp_C',
#        'coolant_temp_C', 'ambient_temp_C', 'vibration_x_g', 'vibration_y_g',
#        'vibration_z_g', 'surface_roughness_Ra', 'dimensional_error_mm',
#        'tool_wear_mm', 'cycle_time_s', 'fault_label'],
#       dtype='object')

# %%
X= df[['sample_id', 'timestamp_s', 'spindle_speed_rpm', 'feed_rate_mm_min',
       'depth_of_cut_mm', 'cutting_speed_m_min', 'material_hardness_HRC',
       'spindle_motor_current_A', 'spindle_torque_Nm', 'spindle_temp_C',
       'coolant_temp_C', 'ambient_temp_C', 'vibration_x_g', 'vibration_y_g',
       'vibration_z_g', 'surface_roughness_Ra', 'dimensional_error_mm',
       'tool_wear_mm', 'cycle_time_s']]
y=df['fault_label']

# %%
from sklearn.model_selection import train_test_split 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
X_train.head()
# Out:
#       sample_id  timestamp_s  spindle_speed_rpm  feed_rate_mm_min  \
# 836         837       9674.3               1301             164.0
# 575         576       6652.8               1058             165.3
# 557         558       6455.4               1050             180.6
# 1235       1236      14305.5               1354             226.9
# 1360       1361      15746.8               1178             149.3
#
#       depth_of_cut_mm  cutting_speed_m_min  material_hardness_HRC  \
# 836              1.90                 0.33                   38.4
# 575              0.89                 0.27                   44.0
# 557              1.15                 0.26                   42.2
# 1235             1.79                 0.34                   47.1
# 1360             1.60                 0.30                   20.0
#
#       spindle_motor_current_A  spindle_torque_Nm  spindle_temp_C  \
# 836                     13.94              17.63            60.4
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()

# %%
X_train_scaled= scaler.fit_transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[-0.27805664, -0.28119783,  0.67295851, ..., -0.50990942,
#         -0.58948025, -0.82082943],
#        [-0.73316439, -0.73590212, -0.9441726 , ..., -0.67134337,
#         -0.73493438, -0.61069024],
#        [-0.76455113, -0.76560876, -0.99741149, ..., -0.54659895,
#         -0.65434493,  1.25054265],
#        ...,
#        [-0.23620765, -0.24015932,  0.220428  , ..., -0.4878957 ,
#         -0.2346901 , -0.82082943],
#        [ 0.80827336,  0.80295927,  1.05894042, ..., -0.15035197,
#          0.75400488, -1.66138622],
#        [ 0.22761864,  0.22881139,  2.29008963, ..., -0.41207066,
#          0.2547434 , -0.19041184]], shape=(1400, 19))

# %%
print(y_train.value_counts().sort_index())
# Out:
# fault_label
# 0    1086
# 1     203
# 2      56
# 3      55
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42, n_jobs=-1)

# %%
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_jobs=-1, random_state=42)
